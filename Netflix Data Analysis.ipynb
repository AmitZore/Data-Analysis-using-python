# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nx = pd.read_csv(r'D:\Neox\Data_Analysts\Data\Netflix Dataset.csv')

# %%
nx
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
nx.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
nx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
nx.shape
# Out:
# (7789, 11)

# %%
nx.size
# Out:
# 85679

# %%
nx.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
nx.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# find the duplicate values and if there is duplicate values remove it

# %%
nx[nx.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
nx.drop_duplicates(inplace=True)

# %%
# is there null values in data set if yes then show in heat map

# %%
nx.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(nx.isnull())
plt.title("Null values ")
plt.show()

# %%
# for house of cards what is the show id and who is the director of this show

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
nx [nx['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
nx [ nx['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# in which year highest number of tv show and movies where released in bar graphs

# %%
nx.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_M          datetime64[ns]
# dtype: object

# %%
nx['Date_M'] = pd.to_datetime(nx['Release_Date'])

# %%
nx['Date_M'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_M, dtype: int64

# %%
# Bar graphs

# %%
nx['Date_M'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# how many movies & tv shows are in the dataset show with bar graphs

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_M
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
nx.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
nx.groupby('Category').Category.count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
sns.countplot(nx['Category'])
# Out:
# C:\Users\AMIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
# movies where released in year 2020

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_M    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
nx['Year'] = nx['Date_M'].dt.year

# %%
nx.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_M          datetime64[ns]
# Year                   float64
# dtype: object

# %%
nx [ (nx['Category'] =='Movie') & (nx['Year']== 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
# show titles of tv shows that where released in india only

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_M    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
nx [ (nx['Category'] =='TV Show') & (nx['Country']=='India') ]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country  \
# ...

# %%
# show top 10 direcotes who gave the highest number of tv shows and movies

# %%
nx['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %%
nx['Director'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# All ther records where category is Movie and type is comedies or country is united kingdom

# %%
nx.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_M    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
nx[ (nx['Category'] =='Movie' ) & (( nx['Type'] =='Comedies') | ( nx['Country'] =='United Kingdom' )) ]
# Out:
#      Show_Id Category                   Title                Director  \
# 19       s20    Movie                     '89                     NaN
# 33       s34    Movie            #realityhigh        Fernando Lebrija
# 72       s73    Movie                17 Again             Burr Steers
# 82       s83    Movie     2036 Origin Unknown           Hasraf Dulull
# 84       s85    Movie               21 & Over  Jon Lucas, Scott Moore
# ...      ...      ...                     ...                     ...
# 7634   s7633    Movie            Wine Country             Amy Poehler
# 7649   s7648    Movie           Without Gorky          Cosima Spender
# 7664   s7663    Movie                 Work It           Laura Terruso
# 7688   s7687    Movie  XV: Beyond the Tryline        Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu             James Brown
#
#                                                    Cast         Country  \
# ...

# %%
# in how many movies/tv shows where tom cruise where cast

# %%
nx.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_M    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
nx[ nx['Cast'] =='Tom Cruise' ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_M, Year]
# Index: []

# %%
nx[ nx['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_M    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
nx.isna()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description  Date_M   Year
# ...

# %%
nx.dropna(inplace=True)

# %%
nx
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# diffrent rating defined by netflix

# %%
nx['Rating'].nunique()
# Out:
# 14

# %%
nx['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# how many movies got 'TV-14' rating in canada

# %%
nx.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description     Date_M    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
nx[ (nx['Category'] =='Movie') & (nx['Rating'] == 'TV-14') & (nx['Country'] =='Canada') ]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %%
# how many tv shows got 'R' rating afteer 2018

# %%
nx.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description     Date_M    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
nx[ (nx['Category']=='TV Show') & (nx['Rating']=='R') & (nx['Year'] > 2018) ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_M, Year]
# Index: []

# %%
# maximun duration of Movies/Shows on Netflix

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_M    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
nx['Duration'].unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
nx[['Min', 'Unit']] = nx['Duration'].str.split(' ', expand=True)

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_M    Year Min  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0  78
#
#   Unit
# 1  min
# 2  min

# %%
nx['Min'].max()
# Out:
# '99'

# %%
# which country has highest number of tv shows

# %%
nx.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_M    Year Min  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0  78
#
#   Unit
# 1  min
# 2  min

# %%
nxn = nx[nx['Category']=='TV Show']

# %%
 nxn.head(2)
# Out:
#     Show_Id Category      Title     Director  \
# 5        s6  TV Show         46  Serdar Akar
# 132    s133  TV Show  7 (Seven)  Nizar Shafi
#
#                                                   Cast Country   Release_Date  \
# 5    Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey   July 1, 2017
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...   India  July 30, 2019
#
#     Rating  Duration                                             Type  \
# 5    TV-MA  1 Season  International TV Shows, TV Dramas, TV Mysteries
# 132  TV-14  1 Season                                         TV Shows
#
#                                            Description     Date_M    Year Min  \
# 5    A genetics professor experiments with a treatm... 2017-07-01  2017.0   1
# 132  Multiple women report their husbands as missin... 2019-07-30  2019.0   1
#
#        Unit
# 5    Season
# 132  Season

# %%
nxn.Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Thailand                                                          3
# Canada                                                            3
# Nigeria                                                           3
# France                                                            3
# United States, Canada                                             2
# ...

# %%
nxn.Country.value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %%
# Sort dataset by year

# %%
nx.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                        Title  \
# 2269   s2270    Movie                   Fred Claus
# 2349   s2350    Movie                    Gangaajal
# 6248   s6248    Movie           The Creative Brain
# 1673   s1674    Movie                  Death of Me
# 7147   s7146    Movie  Tony Parker: The Final Shot
# ...      ...      ...                          ...
# 2041   s2042    Movie                Even the Rain
# 3840   s3841    Movie  Mad Ron's Prevues from Hell
# 3248   s3249    Movie      Just Another Love Story
# 5766   s5766    Movie                     Splatter
# 7115   s7114    Movie         To and From New York
#
#                              Director  \
# 2269                     David Dobkin
# 2349                      Prakash Jha
# 6248  Jennifer Beamish, Toby Trackman
# 1673              Darren Lynn Bousman
# 7147                    Florent Bodin
# ...                               ...
# 2041                    Icíar Bollaín
# ...

# %%
# categorys is movies and type a drama

# %%
nx.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description     Date_M    Year Min  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
#
#   Unit
# 1  min

# %%
nx [(nx['Category']== 'Movie') & (nx['Type'] =='Dramas') ]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
#catergory is tv show and type kihs tv

# %%
nx.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description     Date_M    Year Min  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
#
#   Unit
# 1  min

# %%
nx[( nx['Category']=='TV Show') & (nx['Type'] =="Kids TV") ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_M, Year, Min, Unit]
# Index: []
